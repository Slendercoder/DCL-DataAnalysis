# %% [markdown]
# ### Analizando resultados parámetros por pareja

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

sns.set()

df_dyads = pd.read_csv('../Data/humans_only_absent.csv')
df_fitted = pd.read_csv('../Data/Dyads/dyads-fitted.csv')
df_classification = pd.read_csv('../Data/classificationDL.csv')

# %%
complemento = {'RS':'RS',
               'ALL':'NOTHING', 'NOTHING':'ALL',
               'TOP':'BOTTOM', 'BOTTOM': 'TOP',
               'LEFT':'RIGHT', 'RIGHT':'LEFT',
               'IN':'OUT', 'OUT':'IN'
              }
ordenar = {'OUT-IN': 'IN-OUT', 'RIGHT-LEFT':'LEFT-RIGHT', 'BOTTOM-TOP':'TOP-BOTTOM', 'NOTHING-ALL':'ALL-NOTHING'}
dyad_dl = {}
difficult_dyads = []
for dyad, Grp in df_dyads.groupby('Dyad'):
    codes = []
    inicial = True
    dlindx = Grp['DLIndex'].mean()
    for player, grp in Grp.groupby('Player'):
        df = grp.groupby('Category')['DLIndex'].mean().reset_index()
        #print(df)
        m = df['DLIndex'].max()
        codes.append(df[df['DLIndex']==m].Category.tolist()[0])
#    code = ordenar[code] if code in ordenar.keys() else code
    #print("****\nDyad", dyad, "with code", code, "and DLindex", dlindx)
# Out:
# 32 {'140-615': 'IN-OUT', '142-263': 'RS-RS', '151-962': 'RS-RS', '216-713': 'RS-RS', '251-716': 'TOP-BOTTOM', '261-970': 'ALL-NOTHING', '277-491': 'TOP-BOTTOM', '331-863': 'BOTTOM-NOTHING', '352-425': 'ALL-NOTHING', '354-344': 'TOP-BOTTOM', '356-137': 'ALL-NOTHING', '416-710': 'ALL-NOTHING', '419-723': 'LEFT-RIGHT', '435-261': 'LEFT-RIGHT', '462-640': 'ALL-NOTHING', '469-569': 'LEFT-RIGHT', '475-186': 'RS-RS', '483-710': 'RS-RS', '487-811': 'ALL-NOTHING', '538-623': 'LEFT-RIGHT', '546-111': 'TOP-BOTTOM', '598-684': 'RS-RS', '618-522': 'RS-RS', '637-838': 'LEFT-RIGHT', '648-175': 'LEFT-RIGHT', '687-660': 'RS-RS', '768-541': 'TOP-BOTTOM', '825-534': 'TOP-BOTTOM', '880-349': 'RS-RS', '938-219': 'ALL-NOTHING', '947-704': 'LEFT-RIGHT', '948-444': 'LEFT-RIGHT'}

# %%
for dyad, Grp in df_dyads.groupby('Dyad'):
    if dyad in difficult_dyads:
        dlindx = Grp['DLIndex'].mean()
        print("Dyad", dyad, "DLindex", dlindx)
# Out:
# Dyad 152-727 DLindex 0.6380208333333334
# Dyad 269-653 DLindex 0.5696022727272727
# Dyad 303-869 DLindex 0.859375
# Dyad 313-199 DLindex 0.2078125
# Dyad 359-904 DLindex 0.6789772727272727
# Dyad 379-897 DLindex 0.44711538461538464
# Dyad 444-475 DLindex 0.5060096153846154
# Dyad 505-833 DLindex 0.6484375
# Dyad 538-623 DLindex 0.44625
# Dyad 588-564 DLindex 0.9635416666666666
# Dyad 590-286 DLindex 0.6080729166666666
# Dyad 636-625 DLindex 0.5413602941176471
# Dyad 656-979 DLindex 0.79375
# Dyad 711-459 DLindex 0.453125

# %%
df_dyads = df_dyads.groupby('Dyad')['DLIndex'].mean().reset_index()
df_dyads.head()
# Out:
#       Dyad   DLIndex
# 0  140-615  0.707031
# 1  142-263  0.495312
# 2  151-962  0.490885
# 3  152-727  0.638021
# 4  216-713  0.079687

# %%
df_classification = df_classification[['Dyad', 'DL']]
df = pd.concat([df_dyads, df_classification], axis=1)
df.columns = ['Dyad', 'DLIndex', 'Dyad1', 'DL']
del df['Dyad1']
df.head()
# Out:
#       Dyad   DLIndex              DL
# 0  140-615  0.707031  Inside-Outside
# 1  142-263  0.495312              RS
# 2  151-962  0.490885              RS
# 3  152-727  0.638021              RS
# 4  216-713  0.079687         All-All

# %%
fig = plt.figure(figsize=(10,6))
ax = sns.stripplot(x='DL', y='DLIndex', data=df)
plt.xlabel('Split')
plt.ylabel('DLindex')
plt.show()

# %%
dict1 = {k: v for k, v in zip(df['Dyad'], df['DLIndex'])}
dict2 = {k: v for k, v in zip(df['Dyad'], df['DL'])}
df_fitted['DLindex'] = df_fitted['Dyad'].map(dict1)
df_fitted['DL'] = df_fitted['Dyad'].map(dict2)
df_fitted.sort_values(by='DLindex', ascending=False, inplace=True)
df_fitted.head(2)
# Out:
#         Dyad Model            wA            wN        wL        wI      alpha  \
# 134  948-444   FRA  8.186729e-12  2.159315e-05  0.000100  0.000007  999.99885
# 133  948-444  WSLS  8.381578e-05  7.267938e-09  0.125182  0.000083  999.99927
#
#            beta      gamma     delta     epsilon      zeta       dev  DLindex  \
# 134  999.999981  11.152907  1.456023  999.953862  0.830747  2.800091      1.0
# 133  999.999969  23.330981  0.000000    0.000000  0.000000  5.600291      1.0
#
#              DL Modelado
# 134  Left-Right  MBiases
# 133  Left-Right  MBiases

# %%
df_fitted[df_fitted['Model']=='WSLS'].sort_values(by='Dyad')
# Out:
#         Dyad Model            wA            wN            wL            wI  \
# 1    140-615  WSLS  4.157314e-02  4.166922e-02  2.956391e-08  6.363226e-02
# 4    142-263  WSLS  1.416396e-06  2.169374e-06  1.653377e-08  6.275624e-06
# 7    151-962  WSLS  1.075755e-05  7.739011e-06  7.937218e-06  6.429288e-06
# 10   152-727  WSLS  1.428353e-01  2.198271e-02  2.583739e-12  1.275531e-07
# 13   216-713  WSLS  2.500000e-01  1.000051e-04  9.999955e-05  1.000066e-04
# 16   251-716  WSLS  8.327465e-02  1.889104e-06  9.122104e-08  1.021954e-07
# 19   261-970  WSLS  1.673116e-01  1.435845e-01  2.886094e-08  7.566170e-14
# 22   269-653  WSLS  1.778133e-01  6.667820e-02  5.186783e-11  2.470865e-07
# 25   277-491  WSLS  5.750616e-06  1.038700e-05  9.425045e-08  3.160073e-05
# 28   303-869  WSLS  6.248005e-02  6.938894e-17  0.000000e+00  0.000000e+00
# 31   313-199  WSLS  4.339711e-02  2.500000e-01  1.000068e-04  1.000016e-04
# 34   331-863  WSLS  1.999413e-01  1.143633e-01  6.084351e-08  3.798489e-13
# 37   352-425  WSLS  2.500000e-01  2.500000e-01  1.000139e-04  1.000152e-04
# 40   354-344  WSLS  1.998695e-02  1.509257e-09  3.907538e-10  3.608225e-15
# 118  4.974215e-08   999.987628  5.494836e-03    0.0      0.0   0.0   8.003227
# 121  9.987462e+02   999.999986  3.199970e+01    0.0      0.0   0.0   2.875713
# 124  9.976821e+02   999.596284  2.524771e+01    0.0      0.0   0.0   0.052784
# 127  7.181489e+00  1000.000000  1.645244e+00    0.0      0.0   0.0  29.517139
# 130  9.999925e+02   999.000000  8.957179e+00    0.0      0.0   0.0  25.096246
# 133  9.999993e+02   999.999969  2.333098e+01    0.0      0.0   0.0   5.600291
#
#       DLindex               DL Modelado
# 1    0.707031   Inside-Outside  MBiases
# 4    0.495312               RS      FRA
# 7    0.490885               RS     WSLS
# 10   0.638021               RS  MBiases
# 13   0.079687          All-All      FRA
# 16   0.836648       Top-Bottom     WSLS
# 19   0.657670       Top-Bottom  MBiases
# 22   0.569602               RS  MBiases
# 25   0.933894       Top-Bottom      FRA
# 28   0.859375              Mix  MBiases
# 31   0.207813  Nothing-Nothing  MBiases
# 34   0.916667       Top-Bottom  MBiases
# 37   0.946875      All-Nothing  MBiases
# 40   0.773849       Top-Bottom     WSLS
# 43   0.994318      All-Nothing  MBiases
# 46   0.678977      All-Nothing  MBiases
# 49   0.447115               RS  MBiases
# 52   0.964286       Left-Right  MBiases
# 55   0.984375       Left-Right  MBiases
# 58   0.868566      All-Nothing  MBiases
# 61   0.506010               RS     WSLS
# 64   0.776786       Left-Right  MBiases
# 67   0.937500      All-Nothing  MBiases
# 70   0.152344  Nothing-Nothing  MBiases
# 73   0.380682               RS     WSLS
# 76   0.704861      All-Nothing  MBiases
# 79   0.648438               RS  MBiases
# 82   0.446250               RS  MBiases
# 85   0.995117       Top-Bottom      FRA
# 88   0.963542       Top-Bottom     WSLS
# 91   0.608073               RS  MBiases
# 94   0.511161               RS     WSLS
# 97   0.496875               RS      FRA
# 100  0.541360               RS  MBiases
# 103  0.891544       Left-Right  MBiases
# 106  0.903125       Left-Right  MBiases
# 109  0.793750       Left-Right  MBiases
# 112  0.354911               RS     WSLS
# 115  0.453125               RS      FRA
# 118  0.782670       Top-Bottom     WSLS
# 121  0.926215       Top-Bottom     WSLS
# 124  0.047697  Nothing-Nothing     WSLS
# 127  0.698864      All-Nothing  MBiases
# 130  0.696429       Left-Right  MBiases
# 133  1.000000       Left-Right  MBiases

# %%
fig = plt.figure(figsize=(30,4))
modelos = df_fitted['Model'].unique()
for i, modelo in enumerate(modelos):
    df = df_fitted[df_fitted['Model']==modelo]
    plt.subplot(1,3,i+1)
    ax = sns.stripplot(x='DL', y='dev', data=df)
    ax.set_ylim([-5,120])
    plt.xlabel('Split')
    plt.ylabel('dev')
    plt.title(modelo)
plt.show()

# %%
df_fitted.groupby('Model')['dev'].sum()
# Out:
# Model
# FRA         647.561479
# MBiases    1709.624831
# WSLS        731.054501
# Name: dev, dtype: float64

# %%
dic = {}
for dyad, grp in df_fitted.groupby('Dyad'):
    Maxi = grp['dev'].max(),
    Model = grp[grp['dev'] == Maxi]['Model'].tolist()[0]
    dic[dyad] = Model

df_fitted['Modelado'] = df_fitted['Dyad'].map(dic)
df_fitted.head()
# Out:
#         Dyad    Model            wA            wN        wL            wI  \
# 134  948-444      FRA  8.186729e-12  2.159315e-05  0.000100  7.360080e-06
# 133  948-444     WSLS  8.381578e-05  7.267938e-09  0.125182  8.298721e-05
# 132  948-444  MBiases  0.000000e+00  0.000000e+00  0.239129  3.568461e-11
# 86   546-111      FRA  1.997687e-01  2.053552e-01  0.168591  1.920470e-01
# 85   546-111     WSLS  2.223940e-01  1.330441e-01  0.231313  9.418812e-02
#
#           alpha        beta      gamma      delta     epsilon      zeta  \
# 134  999.998850  999.999981  11.152907   1.456023  999.953862  0.830747
# 133  999.999270  999.999969  23.330981   0.000000    0.000000  0.000000
# 132    0.000000    0.000000   0.000000   0.000000    0.000000  0.000000
# 86   923.952442  999.643951  14.126669  32.069998  999.668571  0.801263
# 85   302.568652  999.943608  24.976592   0.000000    0.000000  0.000000
#
#            dev   DLindex          DL Modelado
# 134   2.800091  1.000000  Left-Right  MBiases
# 133   5.600291  1.000000  Left-Right  MBiases
# 132  69.223818  1.000000  Left-Right  MBiases
# 86    0.000000  0.995117  Top-Bottom      FRA
# 85    0.000000  0.995117  Top-Bottom      FRA

# %%
df = df_fitted[df_fitted['Modelado']=='FRA']
df = df[df['Model']==df['Modelado']]
print(df.shape)
df.head(7)
# Out:
# (6, 16)
#         Dyad Model            wA            wN            wL            wI  \
# 86   546-111   FRA  1.997687e-01  2.053552e-01  1.685915e-01  1.920470e-01
# 26   277-491   FRA  5.866620e-05  1.887821e-06  1.805617e-08  7.824451e-07
# 98   618-522   FRA  3.610966e-08  4.122793e-05  1.329589e-06  4.927841e-08
# 5    142-263   FRA  6.623892e-07  7.475312e-05  1.440019e-06  9.886768e-07
# 116  711-459   FRA  1.852013e-02  7.291331e-11  6.776271e-07  9.259030e-03
# 14   216-713   FRA  2.500000e-01  1.000104e-04  1.000088e-04  1.000006e-04
#
#           alpha        beta      gamma         delta     epsilon      zeta  \
# 86   923.952442  999.643951  14.126669  3.207000e+01  999.668571  0.801263
# 26     0.000032  999.654583   0.199356  7.229312e-07  999.997143  0.998271
# 98    72.603430  999.999770   3.290345  9.999966e+02  999.999992  1.000000
# 5    997.799447  999.995467  32.000000  1.373165e-02  999.005695  1.000000
# 116  853.972594  999.228454  30.988417  1.241426e-07  999.000052  0.999916
# 14   999.996763  999.170865  31.999997  0.000000e+00  999.000029  0.500037
#
#            dev   DLindex          DL Modelado
# 86    0.000000  0.995117  Top-Bottom      FRA
# 26    0.001600  0.933894  Top-Bottom      FRA
# 98    0.041588  0.496875          RS      FRA
# 5     0.052784  0.495312          RS      FRA
# 116  10.660606  0.453125          RS      FRA
# 14   50.931906  0.079687     All-All      FRA

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

xs = list(df['delta'])
ys = list(df['zeta'])
zs = list(df['DLindex'])
ax.scatter(xs, ys, zs)

ax.set_xlabel('delta')
ax.set_ylabel('zeta')
ax.set_zlabel('DLindex')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
columnas = df.columns.tolist()[6:12]
for i, col in enumerate(columnas):
    plt.subplot(2,3,i+1)
    ax=sns.scatterplot(df[col], df['DLindex'], hue=df['DL'])
