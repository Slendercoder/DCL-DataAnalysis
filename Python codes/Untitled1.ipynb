# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('../Data/output0.csv')
data.head()
# Out:
#    index        Dyad  Round  Player  Answer  Time  a11  a12  a13  a14  ...  \
# 0      0  1047795881      1  104776  Absent    32    0    0    0    1  ...
# 1      0  1047795881      2  104776  Absent    32    1    0    0    0  ...
# 2      0  1047795881      3  104776  Absent    32    1    0    1    0  ...
# 3      0  1047795881      4  104776  Absent    32    0    0    1    1  ...
# 4      0  1047795881      5  104776  Absent    32    0    0    0    1  ...
#
#     DLIndex  Similarity  Score_LAG1  Norm_Score_LAG1  Consistency_LEAD1  \
# 0  0.375000    0.406250         NaN              NaN           0.315789
# 1  0.468750    0.375000        28.0          0.97500           0.191489
# 2  0.546875    0.500000       -80.0          0.30000           0.341463
# 3  0.484375    0.359375       -71.0          0.35625           0.190476
# 4  0.421875    0.421875       -74.0          0.33750           0.175000
#
#    Dif_consist_LAG1  Category_LAG1  RegionGo  RegionGo2  Similarity_LAG1
# ...

# %%
sns.lineplot(x=data['Round'], y=data['DLIndex'])
