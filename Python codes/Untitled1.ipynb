# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Load data from sweeping **shaky hand parameter**

# %%
df_list = []
for p in [0, 3, 6]:
    archivo = '../Data/output-shaky-' + str(p) + '-0.csv' 
    try:
        aux = pd.read_csv(archivo)
        aux['Parameter'] = p
        df_list.append(aux)
    except:
        pass

data = pd.concat(df_list)
data.head()
# Out:
#    index        Dyad  Round  Player  Answer  Time  a11  a12  a13  a14  ...  \
# 0      0  1047052381      1  104700  Absent    32    1    0    1    0  ...
# 1      0  1047052381      2  104700  Absent    32    1    1    0    0  ...
# 2      0  1047052381      3  104700  Absent    33    1    1    0    0  ...
# 3      0  1047052381      4  104700  Absent    62    1    1    1    1  ...
# 4      0  1047052381      5  104700  Absent     2    0    0    0    0  ...
#
#    Similarity  Score_LAG1  Norm_Score_LAG1  Consistency_LEAD1  \
# 0    0.368421         NaN              NaN           0.194444
# 1    0.359375       -73.0          0.34375           0.119048
# 2    0.375000       -74.0          0.33750           0.375000
# 3    1.000000        21.0          0.93125           0.000000
# 4    1.000000        -6.0          0.76250           1.000000
#
#    Dif_consist_LAG1  Category_LAG1  RegionGo  RegionGo2  Similarity_LAG1  \
# ...

# %% [markdown]
# Load data from sweeping **Alpha parameter**

# %%
df_list = []
for p in [0.2, 0.4, 0.6, 0.8, 1]:
    archivo = '../Data/Sweeps/out_Alpha_' + str(p) + '.csv' 
    try:
        aux = pd.read_csv(archivo)
        aux['Parameter'] = p
        df_list.append(aux)
    except:
        pass

data = pd.concat(df_list)
data.head()
# Out:
#    index        Dyad  Round  Player   Answer  Time  a11  a12  a13  a14  ...  \
# 0      0  1031332147      1  103135  Present    12    0    0    0    0  ...
# 1      0  1031332147      2  103135   Absent    32    1    0    0    1  ...
# 2      0  1031332147      3  103135   Absent    32    1    0    1    1  ...
# 3      0  1031332147      4  103135   Absent    32    0    0    1    1  ...
# 4      0  1031332147      5  103135   Absent    32    0    0    1    0  ...
#
#    Score_LAG1  Norm_Score_LAG1  Consistency_LEAD1  Dif_consist_LAG1  \
# 0         NaN              NaN           0.195122               NaN
# 1        30.0          0.98750           0.268293               NaN
# 2       -75.0          0.33125           0.435897          0.028455
# 3       -73.0          0.34375           0.302326          0.125436
# 4        23.0          0.94375           0.309524          0.172740
#
#    Category_LAG1  RegionGo  RegionGo2  Similarity_LAG1  Alpha  Shaky
# ...

# %% [markdown]
# Load data from sweeping **Delta parameter**

# %%
df_list = []
for p in [0.8, 0.9, 1, 1.1, 1.2]:
    archivo = '../Data/Sweeps/out_Delta_' + str(p) + '.csv' 
    try:
        aux = pd.read_csv(archivo)
        aux['Parameter'] = p
        df_list.append(aux)
    except:
        pass

data = pd.concat(df_list)
data.head()
# Out:
#    index        Dyad  Round  Player   Answer  Time  a11  a12  a13  a14  ...  \
# 0      0  1157969409      1  115796  Present    22    0    0    0    0  ...
# 1      0  1157969409      2  115796   Absent    32    0    1    0    0  ...
# 2      0  1157969409      3  115796   Absent    32    1    1    1    0  ...
# 3      0  1157969409      4  115796   Absent    32    1    1    1    0  ...
# 4      0  1157969409      5  115796   Absent    32    0    0    1    0  ...
#
#    Score_LAG1  Norm_Score_LAG1  Consistency_LEAD1  Dif_consist_LAG1  \
# 0         NaN              NaN           0.288889               NaN
# 1        25.0          0.95625           0.309524               NaN
# 2        24.0          0.95000           0.304348          0.063889
# 3        24.0          0.95000           0.238095          0.087302
# 4        22.0          0.93750           0.171429          0.038509
#
#    Category_LAG1  RegionGo  RegionGo2  Similarity_LAG1  Delta  Parameter
# ...

# %%
sns.lineplot(x=data['Round'], y=data['DLIndex'], hue=data['Parameter'])

# %%
sns.lineplot(x=data['Round'], y=data['Ac_Score'], hue=data['Parameter'])
